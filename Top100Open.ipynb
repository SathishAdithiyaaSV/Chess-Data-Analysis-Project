# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import csv
import time
driver = webdriver.Chrome()  # You need to have chromedriver installed and in your PATH

# URL of the website to scrape
url = 'https://ratings.fide.com/top_lists.phtml'

# Load the webpage
driver.get(url)
time.sleep(5)
table = driver.find_element(By.XPATH, "//*[@id='div_output']/table/tbody")
rows = table.find_elements(By.TAG_NAME, "tr")
with open("sample.csv","w",newline="") as file:
    writer = csv.writer(file)
    for r in rows:
        data=r.find_elements(By.CSS_SELECTOR,"td,th")
        row_data=[]
        for d in data:
            row_data.append(d.text)
        writer.writerow(row_data)


driver.quit()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("sample.csv", header=None, names=["Name", "Country", "Ratings", "+-", "Birth year", "Avg rt"])

# Prepare data for the pie chart
value_counts = df["Country"].value_counts()
pie_data = [value_counts['IND'], value_counts['RUS'], value_counts['USA'], value_counts['CHN']]

pie_labels = ['IND', 'RUS', 'USA', 'CHN']

colors = ['skyblue', 'green', 'red', 'purple']

# Create a pie chart using Matplotlib
plt.figure(figsize=(6, 6))  # Set the figure size
plt.pie(pie_data, labels=pie_labels, autopct="%1.1f%%", colors=colors, startangle=90, wedgeprops={'edgecolor':'black'})  # Plot the pie chart
plt.title("Pie Chart of Top 100 Players distribution country wise ")
plt.show()

# %%
#for india top 100

from selenium import webdriver
from selenium.webdriver.common.by import By
import csv
import time
driver = webdriver.Chrome()  # You need to have chromedriver installed and in your PATH

# URL of the website to scrape
url = 'https://ratings.fide.com/rankings.phtml?continent=0&country=IND&rating=standard&gender=&age1=0&age2=0&period=2024-04-01&period2=1'

# Load the webpage
driver.get(url)
time.sleep(5)
table = driver.find_element(By.XPATH, "//*[@id='div_output']/table/tbody")
rows = table.find_elements(By.TAG_NAME, "tr")
with open("INDIATOP100.csv","w",newline="") as file:
    writer = csv.writer(file)
    for r in rows:
        data=r.find_elements(By.CSS_SELECTOR,"td,th")
        row_data=[]
        for d in data:
            row_data.append(d.text)
        writer.writerow(row_data)


driver.quit()

# %%
#for india 2019 top 100
''''
from selenium import webdriver
from selenium.webdriver.common.by import By
import csv
'''
import time

driver = webdriver.Chrome()  # You need to have chromedriver installed and in your PATH

# URL of the website to scrape
url = 'https://ratings.fide.com/rankings.phtml?continent=0&country=IND&rating=standard&gender=&age1=0&age2=0&period=2019-04-01&period2=1'

# Load the webpage
driver.get(url)
time.sleep(5)
table = driver.find_element(By.XPATH, "//*[@id='div_output']/table/tbody")
rows = table.find_elements(By.TAG_NAME, "tr")
with open("INDIA2019TOP100.csv","w",newline="") as file:
    writer = csv.writer(file)
    for r in rows:
        data=r.find_elements(By.CSS_SELECTOR,"td,th")
        row_data=[]
        for d in data:
            row_data.append(d.text)
        writer.writerow(row_data)


driver.quit()

# %%
#China top 100 2024
'''
from selenium import webdriver
from selenium.webdriver.common.by import By
import csv
'''
driver = webdriver.Chrome()  # You need to have chromedriver installed and in your PATH



# URL of the website to scrape
url = 'https://ratings.fide.com/rankings.phtml?continent=0&country=CHN&rating=standard&gender=&age1=0&age2=0&period=2024-04-01&period2=1'

# Load the webpage
driver.get(url)
time.sleep(5)
table = driver.find_element(By.XPATH, "//*[@id='div_output']/table/tbody")
rows = table.find_elements(By.TAG_NAME, "tr")
with open("CHINATOP100.csv","w",newline="") as file:
    writer = csv.writer(file)
    for r in rows:
        data=r.find_elements(By.CSS_SELECTOR,"td,th")
        row_data=[]
        for d in data:
            row_data.append(d.text)
        writer.writerow(row_data)


driver.quit()

# %%
#Russia top 100 2024

from selenium import webdriver
from selenium.webdriver.common.by import By
import csv
driver = webdriver.Chrome()  # You need to have chromedriver installed and in your PATH

# URL of the website to scrape
url = 'https://ratings.fide.com/rankings.phtml?continent=0&country=RUS&rating=standard&gender=&age1=0&age2=0&period=2024-04-01&period2=1'

# Load the webpage
driver.get(url)
time.sleep(5)
table = driver.find_element(By.XPATH, "//*[@id='div_output']/table/tbody")
rows = table.find_elements(By.TAG_NAME, "tr")
with open("RUSSIATOP100.csv","w",newline="") as file:
    writer = csv.writer(file)
    for r in rows:
        data=r.find_elements(By.CSS_SELECTOR,"td,th")
        row_data=[]
        for d in data:
            row_data.append(d.text)
        writer.writerow(row_data)


driver.quit()

# %%
#USA top 100 2024

from selenium import webdriver
from selenium.webdriver.common.by import By
import csv
driver = webdriver.Chrome()  # You need to have chromedriver installed and in your PATH

# URL of the website to scrape
url = 'https://ratings.fide.com/rankings.phtml?continent=0&country=USA&rating=standard&gender=&age1=0&age2=0&period=2024-04-01&period2=1'

# Load the webpage
driver.get(url)

time.sleep(5)
table = driver.find_element(By.XPATH, "//*[@id='div_output']/table/tbody")
rows = table.find_elements(By.TAG_NAME, "tr")
with open("USATOP100.csv","w",newline="") as file:
    writer = csv.writer(file)
    for r in rows:
        data=r.find_elements(By.CSS_SELECTOR,"td,th")
        row_data=[]
        for d in data:
            row_data.append(d.text)
        writer.writerow(row_data)


driver.quit()

# %%
driver = webdriver.Chrome()

# URL of the website to scrape
url = 'https://ratings.fide.com/rankings.phtml?continent=0&country=USA&rating=standard&gender=&age1=0&age2=0&period=2024-04-01&period2=1'

# Load the webpage
driver.get(url)

time.sleep(5)
table = driver.find_element(By.XPATH, "//*[@id='div_output']/table/tbody")
rows = table.find_elements(By.TAG_NAME, "tr")
with open("USATOP100.csv","w",newline="") as file:
    writer = csv.writer(file)
    for r in rows:
        data=r.find_elements(By.CSS_SELECTOR,"td,th")
        row_data=[]
        for d in data:
            row_data.append(d.text)
        writer.writerow(row_data)


driver.quit()

# %%
driver = webdriver.Chrome()

url = "https://ratings.fide.com/rankings.phtml?continent=0&country=USA&rating=standard&gender=&age1=0&age2=0&period=2019-04-01&period2=1"

driver.get(url)

time.sleep(5)
table = driver.find_element(By.XPATH, "//*[@id='div_output']/table/tbody")
rows = table.find_elements(By.TAG_NAME, "tr")
with open("USA2019TOP100.csv","w",newline="") as file:
    writer = csv.writer(file)
    for r in rows:
        data=r.find_elements(By.CSS_SELECTOR,"td,th")
        row_data=[]
        for d in data:
            row_data.append(d.text)
        writer.writerow(row_data)


driver.quit()

# %%
driver = webdriver.Chrome()

url = "https://ratings.fide.com/rankings.phtml?continent=0&country=RUS&rating=standard&gender=&age1=0&age2=0&period=2019-04-01&period2=1"

driver.get(url)

time.sleep(5)
table = driver.find_element(By.XPATH, "//*[@id='div_output']/table/tbody")
rows = table.find_elements(By.TAG_NAME, "tr")
with open("RUSSIA2019TOP100.csv","w",newline="") as file:
    writer = csv.writer(file)
    for r in rows:
        data=r.find_elements(By.CSS_SELECTOR,"td,th")
        row_data=[]
        for d in data:
            row_data.append(d.text)
        writer.writerow(row_data)


driver.quit()

# %%
driver = webdriver.Chrome()

url = "https://ratings.fide.com/rankings.phtml?continent=0&country=CHN&rating=standard&gender=&age1=0&age2=0&period=2019-04-01&period2=1"

driver.get(url)

time.sleep(5)
table = driver.find_element(By.XPATH, "//*[@id='div_output']/table/tbody")
rows = table.find_elements(By.TAG_NAME, "tr")
with open("CHINA2019TOP100.csv","w",newline="") as file:
    writer = csv.writer(file)
    for r in rows:
        data=r.find_elements(By.CSS_SELECTOR,"td,th")
        row_data=[]
        for d in data:
            row_data.append(d.text)
        writer.writerow(row_data)
6

driver.quit()

# %%
#top 100 india junior

driver = webdriver.Chrome()

url = "https://ratings.fide.com/rankings.phtml?continent=0&country=IND&rating=standard&gender=&age1=0&age2=20&period=2024-04-01&period2=1"
driver.get(url)

time.sleep(5)
table = driver.find_element(By.XPATH, "//*[@id='div_output']/table/tbody")
rows = table.find_elements(By.TAG_NAME, "tr")
with open("INDJRTOP100.csv","w",newline="") as file:
    writer = csv.writer(file)
    for r in rows:
        data=r.find_elements(By.CSS_SELECTOR,"td,th")
        row_data=[]
        for d in data:
            row_data.append(d.text)
        writer.writerow(row_data)
6

driver.quit()

# %%
# top 100 china junior

driver = webdriver.Chrome()

url = "https://ratings.fide.com/rankings.phtml?continent=0&country=CHN&rating=standard&gender=&age1=0&age2=20&period=2024-04-01&period2=1"
driver.get(url)

time.sleep(5)
table = driver.find_element(By.XPATH, "//*[@id='div_output']/table/tbody")
rows = table.find_elements(By.TAG_NAME, "tr")
with open("CHNJRTOP100.csv","w",newline="") as file:
    writer = csv.writer(file)
    for r in rows:
        data=r.find_elements(By.CSS_SELECTOR,"td,th")
        row_data=[]
        for d in data:
            row_data.append(d.text)
        writer.writerow(row_data)
6

driver.quit()

# %%
#top 100 USA junior

driver = webdriver.Chrome()

url = "https://ratings.fide.com/rankings.phtml?continent=0&country=USA&rating=standard&gender=&age1=0&age2=20&period=2024-04-01&period2=1"
driver.get(url)

time.sleep(5)
table = driver.find_element(By.XPATH, "//*[@id='div_output']/table/tbody")
rows = table.find_elements(By.TAG_NAME, "tr")
with open("USAJRTOP100.csv","w",newline="") as file:
    writer = csv.writer(file)
    for r in rows:
        data=r.find_elements(By.CSS_SELECTOR,"td,th")
        row_data=[]
        for d in data:
            row_data.append(d.text)
        writer.writerow(row_data)
6

driver.quit()

# %%
#top 100 RUS junior

driver = webdriver.Chrome()

url = "https://ratings.fide.com/rankings.phtml?continent=0&country=RUS&rating=standard&gender=&age1=0&age2=20&period=2024-04-01&period2=1"
driver.get(url)

time.sleep(5)
table = driver.find_element(By.XPATH, "//*[@id='div_output']/table/tbody")
rows = table.find_elements(By.TAG_NAME, "tr")
with open("RUSJRTOP100.csv","w",newline="") as file:
    writer = csv.writer(file)
    for r in rows:
        data=r.find_elements(By.CSS_SELECTOR,"td,th")
        row_data=[]
        for d in data:
            row_data.append(d.text)
        writer.writerow(row_data)
6

driver.quit()

# %%
#top 100 IND junior 2019

driver = webdriver.Chrome()

url = "https://ratings.fide.com/rankings.phtml?continent=0&country=IND&rating=standard&gender=&age1=0&age2=20&period=2019-04-01&period2=1"
driver.get(url)

time.sleep(5)
table = driver.find_element(By.XPATH, "//*[@id='div_output']/table/tbody")
rows = table.find_elements(By.TAG_NAME, "tr")
with open("INDJR2019TOP100.csv","w",newline="") as file:
    writer = csv.writer(file)
    for r in rows:
        data=r.find_elements(By.CSS_SELECTOR,"td,th")
        row_data=[]
        for d in data:
            row_data.append(d.text)
        writer.writerow(row_data)
6

driver.quit()

# %%
#top 100 CHN junior 2019

driver = webdriver.Chrome()

url = "https://ratings.fide.com/rankings.phtml?continent=0&country=CHN&rating=standard&gender=&age1=0&age2=20&period=2019-04-01&period2=1"
driver.get(url)

time.sleep(5)
table = driver.find_element(By.XPATH, "//*[@id='div_output']/table/tbody")
rows = table.find_elements(By.TAG_NAME, "tr")
with open("CHNJR2019TOP100.csv","w",newline="") as file:
    writer = csv.writer(file)
    for r in rows:
        data=r.find_elements(By.CSS_SELECTOR,"td,th")
        row_data=[]
        for d in data:
            row_data.append(d.text)
        writer.writerow(row_data)
6

driver.quit()

# %%
#top 100 USA junior 2019

driver = webdriver.Chrome()

url = "https://ratings.fide.com/rankings.phtml?continent=0&country=USA&rating=standard&gender=&age1=0&age2=20&period=2019-04-01&period2=1"
driver.get(url)

time.sleep(5)
table = driver.find_element(By.XPATH, "//*[@id='div_output']/table/tbody")
rows = table.find_elements(By.TAG_NAME, "tr")
with open("USAJR2019TOP100.csv","w",newline="") as file:
    writer = csv.writer(file)
    for r in rows:
        data=r.find_elements(By.CSS_SELECTOR,"td,th")
        row_data=[]
        for d in data:
            row_data.append(d.text)
        writer.writerow(row_data)
6

driver.quit()

# %%
#top 100 RUS junior 2019

driver = webdriver.Chrome()

url = "https://ratings.fide.com/rankings.phtml?continent=0&country=RUS&rating=standard&gender=&age1=0&age2=20&period=2019-04-01&period2=1"
driver.get(url)

time.sleep(5)
table = driver.find_element(By.XPATH, "//*[@id='div_output']/table/tbody")
rows = table.find_elements(By.TAG_NAME, "tr")
with open("RUSJR2019TOP100.csv","w",newline="") as file:
    writer = csv.writer(file)
    for r in rows:
        data=r.find_elements(By.CSS_SELECTOR,"td,th")
        row_data=[]
        for d in data:
            row_data.append(d.text)
        writer.writerow(row_data)
6

driver.quit()

# %%
import matplotlib.animation as animation

dfUSA = pd.read_csv("USATOP100.csv", header=None, names=["#", "Name", "Title", "Fed", "Ratings", "Birth year"])

dfIND = pd.read_csv("INDIATOP100.csv", header=None, names=["#", "Name", "Title", "Fed", "Ratings", "Birth year"])

dfCHN = pd.read_csv("CHINATOP100.csv", header=None, names=["#", "Name", "Title", "Fed", "Ratings", "Birth year"])

dfRUS = pd.read_csv("RUSSIATOP100.csv", header=None, names=["#", "Name", "Title", "Fed", "Ratings", "Birth year"])

dfIND2019 = pd.read_csv("INDIA2019TOP100.csv", header=None, names=["#", "Name", "Title", "Fed", "Ratings", "Birth year"])

dfCHN2019 = pd.read_csv("CHINA2019TOP100.csv", header=None, names=["#", "Name", "Title", "Fed", "Ratings", "Birth year"])

dfRUS2019 = pd.read_csv("RUSSIA2019TOP100.csv", header=None, names=["#", "Name", "Title", "Fed", "Ratings", "Birth year"])

dfUSA2019 = pd.read_csv("USA2019TOP100.csv", header=None, names=["#", "Name", "Title", "Fed", "Ratings", "Birth year"])

avgrtUSA = dfUSA["Ratings"].mean()

avgrtIND = dfIND["Ratings"].mean()

avgrtCHN = dfCHN["Ratings"].mean()

avgrtRUS = dfRUS["Ratings"].mean()

avgrtIND2019 = dfIND2019["Ratings"].mean()

avgrtCHN2019 = dfCHN2019["Ratings"].mean()

avgrtRUS2019 = dfRUS2019["Ratings"].mean()

avgrtUSA2019 = dfUSA2019["Ratings"].mean()


plt.figure(figsize=(8, 6))  # Set the figure size (optional)

data1 = [avgrtIND, avgrtUSA, avgrtCHN, avgrtRUS]
data2 = [avgrtIND2019, avgrtUSA2019, avgrtCHN2019, avgrtRUS2019]
cat = ["India", "USA", "China", "Russia"]

# Define bar width  
bar_width = 0.35

# Positions for data1 bars
x1 = [i for i in range(len(cat))]

# Positions for data2 bars (shifted to the right by bar_width)
x2 = [i + bar_width for i in x1]


# Create bars for data1
plt.bar(x1, data2, color='skyblue', width=bar_width, label='April 2019')

# Create bars for data2 (shifted positions)
plt.bar(x2, data1, color='coral', width=bar_width, label='April 2024')

plt.ylim(ymin=2350)  # Set y-axis limits (optional)

plt.xlabel('Country')

plt.ylabel('Average Rating')

plt.title('Rating Analysis for top 100 open')

plt.legend()

plt.xticks([i + bar_width/2 for i in x1], cat)  # Adjust x-axis ticks for better alignment
plt.tight_layout()  # Adjust spacing between elements


plt.show()

#plt.tight_layout()  # Adjust spacing to prevent overlapping elements (optional)

# %%
dfUSAJR = pd.read_csv("USAJRTOP100.csv", header=None, names=["#", "Name", "Title", "Fed", "Ratings", "Birth year"])

dfINDJR = pd.read_csv("INDJRTOP100.csv", header=None, names=["#", "Name", "Title", "Fed", "Ratings", "Birth year"])

dfCHNJR = pd.read_csv("CHNJRTOP100.csv", header=None, names=["#", "Name", "Title", "Fed", "Ratings", "Birth year"])

dfRUSJR = pd.read_csv("RUSJRTOP100.csv", header=None, names=["#", "Name", "Title", "Fed", "Ratings", "Birth year"])

dfIND2019JR = pd.read_csv("INDJR2019TOP100.csv", header=None, names=["#", "Name", "Title", "Fed", "Ratings", "Birth year"])

dfCHN2019JR = pd.read_csv("CHNJR2019TOP100.csv", header=None, names=["#", "Name", "Title", "Fed", "Ratings", "Birth year"])

dfRUS2019JR = pd.read_csv("RUSJR2019TOP100.csv", header=None, names=["#", "Name", "Title", "Fed", "Ratings", "Birth year"])

dfUSA2019JR = pd.read_csv("USAJR2019TOP100.csv", header=None, names=["#", "Name", "Title", "Fed", "Ratings", "Birth year"])

avgrtUSAJR = dfUSA["Ratings"].mean()

avgrtINDJR = dfIND["Ratings"].mean()

avgrtCHNJR = dfCHN["Ratings"].mean()

avgrtRUSJR = dfRUS["Ratings"].mean()

avgrtIND2019JR = dfIND2019["Ratings"].mean()

avgrtCHN2019JR = dfCHN2019["Ratings"].mean()

avgrtRUS2019JR = dfRUS2019["Ratings"].mean()

avgrtUSA2019JR = dfUSA2019["Ratings"].mean()


plt.figure(figsize=(8, 6))  # Set the figure size (optional)

data1 = [avgrtINDJR, avgrtUSAJR, avgrtCHNJR, avgrtRUSJR]
data2 = [avgrtIND2019JR, avgrtUSA2019JR, avgrtCHN2019JR, avgrtRUS2019JR]
cat = ["India", "USA", "China", "Russia"]

# Define bar width  
bar_width = 0.35

# Positions for data1 bars
x1 = [i for i in range(len(cat))]

# Positions for data2 bars (shifted to the right by bar_width)
x2 = [i + bar_width for i in x1]


# Create bars for data1
plt.bar(x1, data2, color='skyblue', width=bar_width, label='April 2019')

# Create bars for data2 (shifted positions)
plt.bar(x2, data1, color='coral', width=bar_width, label='April 2024')

plt.ylim(ymin=2000)  # Set y-axis limits (optional)

plt.xlabel('Country')

plt.ylabel('Average Rating')

plt.title('Rating Analysis for top 100 junior')

plt.legend()

plt.xticks([i + bar_width/2 for i in x1], cat)  # Adjust x-axis ticks for better alignment
plt.tight_layout()  # Adjust spacing between elements
plt.show()


#plt.tight_layout()  # Adjust spacing to prevent overlapping elements (optional)

plt.show()

# %%
df1 = pd.read_csv("INDIATOP100.csv", header=None, names=["#", "Name", "Title", "Fed", "Ratings", "Birth year"])

df1["Age"] = 2024 - df1["Birth year"]
avgrt1 = []

df["Age"] = 2024 - df["Birth year"]
avgrt = []
age_groups = ['10-15', '15-20','20-25', '25-30', '30-35','35-40', '40-45', '45-50', '50-55']  # Age group labels (assuming these were used for bars)

df2 = pd.read_csv("INDIA2019TOP100.csv", header=None, names=["#", "Name", "Title", "Fed", "Ratings", "Birth year"])

df2["Age"] = 2019 - df2["Birth year"]
avgrt2=[]
for i in range(2, 11):
  avgrt2.append(df2[(df2["Age"] >= i*5) & (df2["Age"] < (i+1)*5)]["Ratings"].mean())

for i in range(2, 11):
  avgrt1.append(df1[(df1["Age"] >= i*5) & (df1["Age"] < (i+1)*5)]["Ratings"].mean())

dfUSA["Age"] = 2024 - dfUSA["Birth year"]
avgrtUSA=[]
for i in range(2, 11):
  avgrtUSA.append(dfUSA[(dfUSA["Age"] >= i*5) & (dfUSA["Age"] < (i+1)*5)]["Ratings"].mean())

dfUSA2019["Age"] = 2019 - dfUSA2019["Birth year"]
avgrtUSA2019=[]
for i in range(2, 11):
  avgrtUSA2019.append(dfUSA2019[(dfUSA2019["Age"] >= i*5) & (dfUSA2019["Age"] < (i+1)*5)]["Ratings"].mean())

dfCHN["Age"] = 2024 - dfCHN["Birth year"]
avgrtCHN=[]
for i in range(2, 11):
  avgrtCHN.append(dfCHN[(dfCHN["Age"] >= i*5) & (dfCHN["Age"] < (i+1)*5)]["Ratings"].mean())

dfCHN2019["Age"] = 2019 - dfCHN2019["Birth year"]
avgrtCHN2019=[]
for i in range(2, 11):
  avgrtCHN2019.append(dfCHN2019[(dfCHN2019["Age"] >= i*5) & (dfCHN2019["Age"] < (i+1)*5)]["Ratings"].mean())

dfRUS["Age"] = 2024 - dfRUS["Birth year"]
avgrtRUS=[]
for i in range(2, 11):
  avgrtRUS.append(dfRUS[(dfRUS["Age"] >= i*5) & (dfRUS["Age"] < (i+1)*5)]["Ratings"].mean())

dfRUS2019["Age"] = 2019 - dfRUS2019["Birth year"]
avgrtRUS2019=[]
for i in range(2, 11):
  avgrtRUS2019.append(dfRUS2019[(dfRUS2019["Age"] >= i*5) & (dfRUS2019["Age"] < (i+1)*5)]["Ratings"].mean())

plt.figure(figsize=(8, 6))  # Set the figure size (optional)
plt.plot(age_groups, avgrt1, color="red", label="India April 2024", marker='o')  # Replace plt.bar() with plt.plot() for line graph
plt.plot(age_groups, avgrt2, color = "orange", label="India April 2019", marker='o')

plt.ylim(ymin=2400)  # Set y-axis limits (optional)

plt.xlabel('Age')
plt.ylabel('Average Rating')
plt.title('Rating Analysis of India Age-wise')

plt.tight_layout()  # Adjust spacing to prevent overlapping elements (optional)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.plot(age_groups, avgrtCHN, color="blue", label="China April 2024", marker='o')
plt.plot(age_groups, avgrtCHN2019, color = "lightblue", label="China April 2019", marker='o')
plt.ylim(ymin=2200)  # Set y-axis limits (optional)

plt.xlabel('Age')
plt.ylabel('Average Rating')
plt.title('Rating Analysis of China Age-wise')

plt.tight_layout()  # Adjust spacing to prevent overlapping elements (optional)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.plot(age_groups, avgrtUSA, color="green", label="USA April 2024", marker='o')
plt.plot(age_groups, avgrtUSA2019, color = "lightgreen", label="USA April 2019", marker='o')
plt.ylim(ymin=2400)  # Set y-axis limits (optional)

plt.xlabel('Age')
plt.ylabel('Average Rating')
plt.title('Rating Analysis of USA Age-wise')

plt.tight_layout()  # Adjust spacing to prevent overlapping elements (optional)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.plot(age_groups, avgrtRUS, color="purple", label="Russia April 2024", marker='o')
plt.plot(age_groups, avgrtRUS2019, color = "pink", label="Russia April 2019", marker='o')
plt.ylim(ymin=2400)  # Set y-axis limits (optional)

plt.xlabel('Age')
plt.ylabel('Average Rating')
plt.title('Rating Analysis of Russia Age-wise')

plt.tight_layout()  # Adjust spacing to prevent overlapping elements (optional)
plt.legend()
plt.show()
